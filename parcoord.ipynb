# %%
getwd()
#dir.create('lib')
# Out:
# [1] "/jupyter_home/dbjerre"

# %%
#install.packages("ggparallel",lib="./lib")

# %%
library("ggparallel",lib="./lib")
library(MASS)
library(RColorBrewer)

# %%
parcoord(data.frame(a=1:5,b=10:6),var.label=T,col=brewer.pal(5,"Accent"),lwd=5)
# Out:
# plot without title

# %%
test <- data.frame(a=factor(letters[1:5]),b=factor(rev(letters)[1:5]))

# %%
test
# Out:
#   a b
# 1 a z
# 2 b y
# 3 c x
# 4 d w
# 5 e v

# %%
ggparallel(list("a","b"),test)
# Out:
# plot without title
